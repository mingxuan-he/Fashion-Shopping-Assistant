# %% [markdown]
# ## The demo code to explore the dataset and create embeddings

# %%
# prepare your openai and pinecone api keys
from openai import OpenAI
from pinecone import Pinecone

# %% [markdown]
# ### Some basic EDA

# %%
import pyarrow.parquet as pq
parquet_file = pq.ParquetFile('data/amazon_fashion_clean_051624.parquet') # modify the path to the parquet file
print(parquet_file.metadata)
# Out:
# <pyarrow._parquet.FileMetaData object at 0x000001999A03D800>
#   created_by: parquet-cpp-arrow version 11.0.0
#   num_columns: 562
#   num_rows: 776976
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 129583

# %%
batch_size = 1000
iterator = parquet_file.iter_batches(batch_size=batch_size)

# %%
# load one batch

batch = next(iterator)
print(batch)
# Out:
# pyarrow.RecordBatch
# title: string
# average_rating: double
# rating_number: int64
# features: string
# description: string
# price: double
# images: list<item: struct<hi_res: string, large: string, thumb: string, variant: string>>
#   child 0, item: struct<hi_res: string, large: string, thumb: string, variant: string>
#       child 0, hi_res: string
#       child 1, large: string
#       child 2, thumb: string
#       child 3, variant: string
# store: string
# details: struct<: string, ABPA Partslink Number: string, ASTM Fluid Rating: string, Active Ingredients: string, Additional product features: string, Age Range (Description): string, Age Range Description: string, Alarm Clock: string, Antibacterial treatment: string, Arch Type: string, Are Batteries Included: string, Aspect Ratio: string, Assembled Depth: string, Assembled Height: string, Assembled Length: string, Assembled Width: string, Assembly Required: string, Assembly required: string, Auto Part Position: string, Auto Shutoff: string, Back Material Type: string, Back Style: string, Band Color: string, Band Length: string, Band Material Type: string, Band Size: string, Band Width: string, Base Material: string, Base Type: string, Batteries: string, Batteries Included?: string, Batteries Required?: string, Batteries required: string, Battery Capacity: string, Battery Cell Composition: string, Battery Cell Type: string, Battery Description: string, Belt Style: string, Best Sellers Rank: struct<Climate Pledge Friendly: double, Climate Pledge Friendly: Apparel: double, Men's Wallets: double, Our Brands: double, Women's Activewear Leggings: double, Women's Activewear T-Shirts: double>, Binding: string, Biometric Security Feature: string, Blade Edge: string, Blade Length: string, Blade Material: string, Blade Shape: string, Blanket Form: string, Body Shape: string, Bottom Shape: string, Bowl Material: string, Brake Width: string, Brand: string, Brand Name: string, Breed Recommendation: string, Brightness: string, Bristle Material: string, Bulb Base: string, CPSIA Cautionary Statement: string, Cable Feature: string, Cable Type: string, Cap Type: string, Capacitance: string, Capacity: string, Capacity 10.3 Ounces: string, Capacity 11 Fluid Ounces: string, Capacity 11 Ounces: string, Capacity 11 Ounces, 15 Ounces: string, Capacity 15 Ounces: string, Capacity 16 Fluid Ounces: string, Capacity 18 Fluid Ounces: string, Capacity Total: string, Care instructions: string, Cartoon Character: string, Case Material: string, Caster Type: string, Cellular Technology: string, Certificate Type: string, Chain Length: string, Chain Type: string, Chamber Depth: string, Chamber Height: string, Chamber Width: string, Charging Time: string, Chest Size: string, Clasp Type: string, Closure: string, Closure Type: string, Collar Style: string, Collection Name: string, Color: string, Color Code: string, Color Name: string, Compatible Devices: string, Compatible Material: string, Compatible Phone Models: string, Connectivity Technology: string, Connector Gender: string, Connector Type: string, Construction Type: string, Control Method: string, Control Type: string, Controller Type: string, Controller Type Button Control: string, Corner Style: string, Country of Origin: string, Country/Region Of Origin: string, Country/Region of origin: string, Cover Material: string, Coverage: string, Current Rating: string, Date First Available: string, Deck Width: string, Denomination Unit: string, Department: string, Design: string, Dial Color: string, Diet Type: string, Display Style: string, Display Technology: string, Display Type: string, Display type: string, Domestic Shipping: string, Dosage Form: string, Drain Type: string, Educational Objective: string, Electric fan design: string, Embellishment: string, Engine Type: string, Extended Length: string, Extension Length: string, Exterior: string, Exterior Finish: string, Eye Relief: string, Fabric Type: string, Fabric Warmth Description: string, Fabric cleaning: string, Fastener Material: string, Fastener Type: string, Fill Material: string, Fill Material Type: string, Filter Class: string, Finish: string, Finish Type: string, Finish types: string, Fit Type: string, Fixture Type: string, Flavor: string, Floor Area: string, Focus Type: string, Form Factor: string, Format: string, Frame Material: string, Frame Material Metal: string, Frame Material Metal, Wood: string, Frame Type: string, Frequency Range: string, Fuel ...
#   child 0, : string
#   child 1, ABPA Partslink Number: string
#   child 2, ASTM Fluid Rating: string
#   child 3, Active Ingredients: string
#   child 4, Additional product features: string
#   child 5, Age Range (Description): string
#   child 6, Age Range Description: string
#   child 7, Alarm Clock: string
#   child 8, Antibacterial treatment: string
#   child 9, Arch Type: string
#   child 10, Are Batteries Included: string
#   child 11, Aspect Ratio: string
#   child 12, Assembled Depth: string
#   child 13, Assembled Height: string
#   child 14, Assembled Length: string
#   child 15, Assembled Width: string
#   child 16, Assembly Required: string
#   child 17, Assembly required: string
#   child 18, Auto Part Position: string
#   child 19, Auto Shutoff: string
#   child 20, Back Material Type: string
#   child 21, Back Style: string
#   child 22, Band Color: string
#   child 23, Band Length: string
#   child 24, Band Material Type: string
#   child 25, Band Size: string
#   child 26, Band Width: string
#   child 27, Base Material: string
#   child 28, Base Type: string
#   child 29, Batteries: string
#   child 30, Batteries Included?: string
#   child 31, Batteries Required?: string
#   child 32, Batteries required: string
#   child 33, Battery Capacity: string
#   child 34, Battery Cell Composition: string
#   child 35, Battery Cell Type: string
#   child 36, Battery Description: string
#   child 37, Belt Style: string
#   child 38, Best Sellers Rank: struct<Climate Pledge Friendly: double, Climate Pledge Friendly: Apparel: double, Men's Wallets: double, Our Brands: double, Women's Activewear Leggings: double, Women's Activewear T-Shirts: double>
#       child 0, Climate Pledge Friendly: double
#       child 1, Climate Pledge Friendly: Apparel: double
#       child 2, Men's Wallets: double
#       child 3, Our Brands: double
#       child 4, Women's Activewear Leggings: double
#       child 5, Women's Activewear T-Shirts: double
#   child 39, Binding: string
#   child 40, Biometric Security Feature: string
#   child 41, Blade Edge: string
#   child 42, Blade Length: string
#   child 43, Blade Material: string
#   child 44, Blade Shape: string
#   child 45, Blanket Form: string
#   child 46, Body Shape: string
#   child 47, Bottom Shape: string
#   child 48, Bowl Material: string
#   child 49, Brake Width: string
#   child 50, Brand: string
#   child 51, Brand Name: string
#   child 52, Breed Recommendation: string
#   child 53, Brightness: string
#   child 54, Bristle Material: string
#   child 55, Bulb Base: string
#   child 56, CPSIA Cautionary Statement: string
#   child 57, Cable Feature: string
#   child 58, Cable Type: string
#   child 59, Cap Type: string
#   child 60, Capacitance: string
#   child 61, Capacity: string
#   child 62, Capacity 10.3 Ounces: string
#   child 63, Capacity 11 Fluid Ounces: string
#   child 64, Capacity 11 Ounces: string
#   child 65, Capacity 11 Ounces, 15 Ounces: string
#   child 66, Capacity 15 Ounces: string
#   child 67, Capacity 16 Fluid Ounces: string
#   child 68, Capacity 18 Fluid Ounces: string
#   child 69, Capacity Total: string
#   child 70, Care instructions: string
#   child 71, Cartoon Character: string
#   child 72, Case Material: string
#   child 73, Caster Type: string
#   child 74, Cellular Technology: string
#   child 75, Certificate Type: string
#   child 76, Chain Length: string
#   child 77, Chain Type: string
#   child 78, Chamber Depth: string
#   child 79, Chamber Height: string
#   child 80, Chamber Width: string
#   child 81, Charging Time: string
#   child 82, Chest Size: string
#   child 83, Clasp Type: string
#   child 84, Closure: string
#   child 85, Closure Type: string
#   child 86, Collar Style: string
#   child 87, Collection Name: string
#   child 88, Color: string
#   child 89, Color Code: string
#   child 90, Color Name: string
#   child 91, Compatible Devices: string
#   child 92, Compatible Material: string
#   child 93, Compatible Phone Models: string
#   child 94, Connectivity Technology: string
#   child 95, Connector Gender: string
#   child 96, Connector Type: string
#   child 97, Construction Type: string
#   child 98, Control Method: string
#   child 99, Control Type: string
#   child 100, Controller Type: string
#   child 101, Controller Type Button Control: string
#   child 102, Corner Style: string
#   child 103, Country of Origin: string
#   child 104, Country/Region Of Origin: string
#   child 105, Country/Region of origin: string
#   child 106, Cover Material: string
#   child 107, Coverage: string
#   child 108, Current Rating: string
#   child 109, Date First Available: string
#   child 110, Deck Width: string
#   child 111, Denomination Unit: string
#   child 112, Department: string
#   child 113, Design: string
#   child 114, Dial Color: string
#   child 115, Diet Type: string
#   child 116, Display Style: string
#   child 117, Display Technology: string
#   child 118, Display Type: string
#   child 119, Display type: string
#   child 120, Domestic Shipping: string
#   child 121, Dosage Form: string
#   child 122, Drain Type: string
#   child 123, Educational Objective: string
#   child 124, Electric fan design: string
#   child 125, Embellishment: string
#   child 126, Engine Type: string
#   child 127, Extended Length: string
#   child 128, Extension Length: string
#   child 129, Exterior: string
#   child 130, Exterior Finish: string
#   child 131, Eye Relief: string
#   child 132, Fabric Type: string
#   child 133, Fabric Warmth Description: string
#   child 134, Fabric cleaning: string
#   child 135, Fastener Material: string
#   child 136, Fastener Type: string
#   child 137, Fill Material: string
#   child 138, Fill Material Type: string
#   child 139, Filter Class: string
#   child 140, Finish: string
#   child 141, Finish Type: string
#   child 142, Finish types: string
#   child 143, Fit Type: string
#   child 144, Fixture Type: string
#   child 145, Flavor: string
#   child 146, Floor Area: string
#   child 147, Focus Type: string
#   child 148, Form Factor: string
#   child 149, Format: string
#   child 150, Frame Material: string
#   child 151, Frame Material Metal: string
#   child 152, Frame Material Metal, Wood: string
#   child 153, Frame Type: string
#   child 154, Frequency Range: string
#   child 155, Fuel Type: string
#   child 156, Furniture Finish: string
#   child 157, GPS: string
#   child 158, Gauge: string
#   child 159, Gem Type: string
#   child 160, Genre: string
#   child 161, Glove Type: string
#   child 162, Golf Club Flex: string
#   child 163, Golf Club Loft: string
#   child 164, Grade Rating: string
#   child 165, Graded By: string
#   child 166, Grip Material: string
#   child 167, Grip Size: string
#   child 168, Grip Type: string
#   child 169, Grit Number: string
#   child 170, Hair Type: string
#   child 171, Hand Orientation: string
#   child 172, Handle Material: string
#   child 173, Handle Type: string
#   child 174, Hardware Interface: string
#   child 175, Has Nonstick Coating: string
#   child 176, Head Style: string
#   child 177, Head Type: string
#   child 178, Height Map: string
#   child 179, Hose Length: string
#   child 180, Human Interface Input: string
#   child 181, Import: string
#   child 182, Import Designation: string
#   child 183, Included Components: string
#   child 184, Incontinence Protector Type: string
#   child 185, Indoor/Outdoor Usage: string
#   child 186, Ink Color: string
#   child 187, Inner Material: string
#   child 188, Input Voltage: string
#   child 189, Inside Pockets: string
#   child 190, Insole Material: string
#   child 191, Insole Type: string
#   child 192, Installation Method: string
#   child 193, Installation Type: string
#   child 194, Installation Type Adhesive: string
#   child 195, Installation Type Peel: string
#   child 196, Installation Type Self-Adhesive: string
#   child 197, Instrument Key: string
#   child 198, Insulation Material: string
#   child 199, International Shipping: string
#   child 200, Is Autographed: string
#   child 201, Is Customizable: string
#   child 202, Is Discontinued By Manufacturer: string
#   child 203, Is Dishwasher Safe: string
#   child 204, Is Foldable: string
#   child 205, Is Stain Resistant: string
#   child 206, Is Waterproof: string
#   child 207, Is framed?: string
#   child 208, Is portable: string
#   child 209, Item Diameter: string
#   child 210, Item Dimensions  LxWxH: string
#   child 211, Item Dimensions LxWxH: string
#   child 212, Item Display Dimensions: string
#   child 213, Item Firmness Description: string
#   child 214, Item Form: string
#   child 215, Item Hardness: string
#   child 216, Item Length: string
#   child 217, Item Length (Description): string
#   child 218, Item Package Dimensions L x W x H: string
#   child 219, Item Package Quantity: string
#   child 220, Item Thickness: string
#   child 221, Item Volume: string
#   child 222, Item Weight: string
#   child 223, Item Weight 14 Pounds: string
#   child 224, Item Weight 31 Pounds: string
#   child 225, Item model number: string
#   child 226, Keyboard Description: string
#   child 227, Lamp Type: string
#   child 228, Language: string
#   child 229, League: string
#   child 230, Lens Coating Description: string
#   child 231, Lens Color: string
#   child 232, Lens Correction Type: string
#   child 233, Lens Material: string
#   child 234, Lens Type: string
#   child 235, Life Vest Type: string
#   child 236, Lifestyle: string
#   child 237, Light Color: string
#   child 238, Light Source Type: string
#   child 239, Light Type: string
#   child 240, Lining Description: string
#   child 241, Liquid Contents Description: string
#   child 242, Liquid Volume: string
#   child 243, Load Capacity: string
#   child 244, Lock Type: string
#   child 245, Locking: string
#   child 246, Magnification Maximum: string
#   child 247, Magnification Strength: string
#   child 248, Main Power Connector Type: string
#   child 249, Manufacturer: string
#   child 250, Manufacturer Minimum Age (MONTHS): string
#   child 251, Manufacturer Part Number: string
#   child 252, Manufacturer recommended age: string
#   child 253, Map Type: string
#   child 254, Material: string
#   child 255, Material Acrylic: string
#   child 256, Material Acrylonitrile Butadiene Styrene: string
#   child 257, Material Alloy Steel: string
#   child 258, Material Aluminum: string
#   child 259, Material Bronze: string
#   child 260, Material Ceramic: string
#   child 261, Material Cotton: string
#   child 262, Material Engineered Wood, Pine, Metal: string
#   child 263, Material Feature: string
#   child 264, Material Glass: string
#   child 265, Material Glass, Acrylonitrile Butadiene Styrene, Polyvinyl ChlorideGlass, Acrylonitrile Butadiene Styrene, Polyvinyl Chloride  See more: string
#   child 266, Material Metal: string
#   child 267, Material Metal, Steel: string
#   child 268, Material Other: string
#   child 269, Material Plastic: string
#   child 270, Material Polyester: string
#   child 271, Material Polyvinyl Chloride: string
#   child 272, Material Silicone: string
#   child 273, Material Stainless Steel: string
#   child 274, Material Stoneware: string
#   child 275, Material Type: string
#   child 276, Material Type Free: string
#   child 277, Material Type(s): string
#   child 278, Material Vinyl: string
#   child 279, Material Weather Resistant Fabric and Plastic: string
#   child 280, Material other: string
#   child 281, Max Input Sheet Capacity: string
#   child 282, Max Printspeed Monochrome: string
#   child 283, Max Temperature Setting: string
#   child 284, Maximum Energy Output: string
#   child 285, Maximum Height: string
#   child 286, Maximum Height Recommendation: string
#   child 287, Maximum Horsepower: string
#   child 288, Maximum Print Speed (Color): string
#   child 289, Maximum Range: string
#   child 290, Maximum Weight Recommendation: string
#   child 291, Maximum weight recommendation: string
#   child 292, Measurement System: string
#   child 293, Measurement Type: string
#   child 294, Media Type: string
#   child 295, Memory Storage Capacity: string
#   child 296, Metal Stamp: string
#   child 297, Metal Type: string
#   child 298, Microphone Form Factor: string
#   child 299, Minimum Age Recomendation: string
#   child 300, Minimum Compatible Size: string
#   child 301, Minimum Height: string
#   child 302, Minimum Weight Recommendation: string
#   child 303, Minimum weight recommendation: string
#   child 304, Mirror Adjustment: string
#   child 305, Model: string
#   child 306, Model Info: string
#   child 307, Model Name: string
#   child 308, Model Year: string
#   child 309, Mounting Type: string
#   child 310, Mounting Type Clip On: string
#   child 311, Mounting Type Insert Mount: string
#   child 312, Mounting Type Tabletop Mount: string
#   child 313, Mounting Type Window Mount: string
#   child 314, Movement Detection Technology: string
#   child 315, National Stock Number: string
#   child 316, Neck Size: string
#   child 317, Neck Style: string
#   child 318, Night vision: string
#   child 319, Noise Attenuation: string
#   child 320, Noise Control: string
#   child 321, Number Of Discs: string
#   child 322, Number Of Items: string
#   child 323, Number Of Pieces: string
#   child 324, Number Of Pockets: string
#   child 325, Number of Batteries: string
#   child 326, Number of Blades: string
#   child 327, Number of Buttons: string
#   child 328, Number of Compartments: string
#   child 329, Number of Dividers: string
#   child 330, Number of Drawers: string
#   child 331, Number of Hooks: string
#   child 332, Number of Items: string
#   child 333, Number of Jets: string
#   child 334, Number of Keys: string
#   child 335, Number of Labels: string
#   child 336, Number of Light Sources: string
#   child 337, Number of Pieces: string
#   child 338, Number of Players: string
#   child 339, Number of Ports: string
#   child 340, Number of Sets: string
#   child 341, Number of Shelves: string
#   child 342, Number of Wheels: string
#   child 343, Number of pieces: string
#   child 344, Number of settings: string
#   child 345, OEM Part Number: string
#   child 346, Occasion: string
#   child 347, Occasion Birthday: string
#   child 348, Occasion Halloween: string
#   child 349, Occasion Travel: string
#   child 350, Occupancy: string
#   child 351, Occupant Capacity: string
#   child 352, Opacity: string
#   child 353, Opening Mechanism: string
#   child 354, Operating System: string
#   child 355, Operating Time: string
#   child 356, Operation Mode: string
#   child 357, Orientation: string
#   child 358, Other camera features: string
#   child 359, Other display features: string
#   child 360, Our Recommended age: string
#   child 361, Outer Material: string
#   child 362, Output Voltage: string
#   child 363, Package Dimensions: string
#   child 364, Package Information: string
#   child 365, Package Type: string
#   child 366, Package Weight: string
#   child 367, Packaging: string
#   child 368, Pages: string
#   child 369, Paint Type: string
#   child 370, Paper Finish: string
#   child 371, Paper Weight: string
#   child 372, Part Number: string
#   child 373, Part number: string
#   child 374, Pattern: string
#   child 375, Perfume: string
#   child 376, Pile Height: string
#   child 377, Pillow Type: string
#   child 378, Pin type: string
#   child 379, Plant or Animal Product Type: string
#   child 380, Platform: string
#   child 381, Ply Rating: string
#   child 382, Pocket Description: string
#   child 383, Point Type: string
#   child 384, Pole Material Type: string
#   child 385, Power Source: string
#   child 386, Pre-printed: string
#   child 387, Pricing: string
#   child 388, Primary Stone Gem Type: string
#   child 389, Printer Output: string
#   child 390, Printing Technology: string
#   child 391, Product Benefits: string
#   child 392, Product Care Instructions: string
#   child 393, Product Dimensions: string
#   child 394, Puzzle type: string
#   child 395, Reading Interest (Max. Age): string
#   child 396, Reading Interest (Min. Age): string
#   child 397, Rechargeable Battery Included: string
#   child 398, Recommended Uses For Product: string
#   child 399, Refill: string
#   child 400, Release date: string
#   child 401, Remote Control Included?: string
#   child 402, Response Time: string
#   child 403, Reusability: string
#   child 404, Rim Size: string
#   child 405, Roast Level: string
#   child 406, Room Type: string
#   child 407, Rug Form Type: string
#   child 408, Ruling Type: string
#   child 409, Safety Rating: string
#   child 410, Scent: string
#   child 411, Screen Size: string
#   child 412, Screen Surface Description: string
#   child 413, Seasons: string
#   child 414, Seat Height: string
#   child 415, Seat Material Type: string
#   child 416, Seat Material Type Suede: string
#   child 417, Sensor Type: string
#   child 418, Shade Color: string
#   child 419, Shade Material: string
#   child 420, Shaft Height: string
#   child 421, Shaft Material: string
#   child 422, Shape: string
#   child 423, Shape Irregular: string
#   child 424, Shape L-Shaped: string
#   child 425, Shape Rectangular: string
#   child 426, Shape Round: string
#   child 427, Sheet Count: string
#   child 428, Sheet Size: string
#   child 429, Shelf Type Corner Shelf: string
#   child 430, Shelf Type Hanging Shelf: string
#   child 431, Shelf Type Wood: string
#   child 432, Shell Type: string
#   child 433, Shirt form type: string
#   child 434, Size: string
#   child 435, Size Map: string
#   child 436, Skill Level: string
#   child 437, Skin Tone: string
#   child 438, Skin Type: string
#   child 439, Sleeve Type: string
#   child 440, Sole Material: string
#   child 441, Special Feature: string
#   child 442, Special Features: string
#   child 443, Special features: string
#   child 444, Specialty: string
#   child 445, Specific Uses For Product: string
#   child 446, Specific instructions for use: string
#   child 447, Specification Met: string
#   child 448, Sport: string
#   child 449, Sport Type: string
#   child 450, Sterility Rating: string
#   child 451, Stone Clarity: string
#   child 452, Stone Color: string
#   child 453, Stone Cut: string
#   child 454, Stone Length: string
#   child 455, Stone Shape: string
#   child 456, Stone Weight: string
#   child 457, Stone Width: string
#   child 458, Stone height: string
#   child 459, Stone treatment method: string
#   child 460, Strap Type: string
#   child 461, Style: string
#   child 462, Sub Brand: string
#   child 463, Suggested Users: string
#   child 464, Supported Application: string
#   child 465, Surface Recommendation: string
#   child 466, Surface Recommendation 2 inch: string
#   child 467, Surface Recommendation Door: string
#   child 468, Surface Recommendation Nail: string
#   child 469, Surface Recommendation Plastic: string
#   child 470, Surface Recommendation Wall: string
#   child 471, Surface Recommendation Window: string
#   child 472, Surface Recommendation Window, Wall: string
#   child 473, Surface Recommendation nail: string
#   child 474, Switch Style: string
#   child 475, Switch Type: string
#   child 476, TV Size: string
#   child 477, Tab Position: string
#   child 478, Tank Volume: string
#   child 479, Target Audience: string
#   child 480, Target Species: string
#   child 481, Target gender: string
#   child 482, Tea Variety: string
#   child 483, Team Name: string
#   child 484, Temperature Rating: string
#   child 485, Tension Level: string
#   child 486, Theme: string
#   child 487, Thickness: string
#   child 488, Thread Type: string
#   child 489, Tick-repellent material: string
#   child 490, Top Material Type: string
#   child 491, Top Style: string
#   child 492, Total Diamond Weight: string
#   child 493, Total Eaches: string
#   child 494, Total Power Outlets: string
#   child 495, Total USB Ports: string
#   child 496, Total gem weight: string
#   child 497, Towel form type: string
#   child 498, Type of Bulb: string
#   child 499, Type of item: string
#   child 500, UPC: string
#   child 501, UV protection: string
#   child 502, Ultraviolet Light Protection: string
#   child 503, Unit Count: string
#   child 504, Unit Grouping: string
#   child 505, Units: string
#   child 506, Usage: string
#   child 507, Use for: string
#   child 508, Vehicle Service Type: string
#   child 509, Vehicle Service Type Passenger Car: string
#   child 510, Voltage: string
#   child 511, Volume: string
#   child 512, Waist (cm): string
#   child 513, Wall Art Form: string
#   child 514, Wallet compartment type: string
#   child 515, Warranty Description: string
#   child 516, Warranty Type: string
#   child 517, Watch Movement: string
#   child 518, Water Resistance Depth: string
#   child 519, Water Resistance Level: string
#   child 520, Water Resistance Technology: string
#   child 521, Wattage: string
#   child 522, Weave Type: string
#   child 523, Weight: string
#   child 524, Weight Limit: string
#   child 525, Whats in the box: string
#   child 526, Wheel Material: string
#   child 527, Wheel Size: string
#   child 528, Wheel Type: string
#   child 529, Wireless Communication Technology: string
#   child 530, Wireless network technology: string
#   child 531, With Lid: string
#   child 532, Year: string
#   child 533, material_composition: string
# parent_asin: string
# title_review_agg: string
# user_id: list<item: string>
#   child 0, item: string
# timestamp: list<item: string>
#   child 0, item: string
# avg_rating_reviewers: double
# coefvar_rating_reviewers: double
# text_agg: string
# text_weighted_agg: string
# images_review_cln: list<item: struct<attachment_type: string, large_image_url: string, medium_image_url: string, small_image_url: string>>
#   child 0, item: struct<attachment_type: string, large_image_url: string, medium_image_url: string, small_image_url: string>
#       child 0, attachment_type: string
#       child 1, large_image_url: string
#       child 2, medium_image_url: string
#       child 3, small_image_url: string
# ----
# -- child 2 type: string
# ["https://m.media-amazon.com/images/I/416BnKa-fLL._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/3104QgcQ6iL._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/31S3C6X6uAL._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/312mloSlacL._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/51lkbfGfufL._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/31O4nM6RZ1L._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/41f-wSrYSBL._AC_SR38,50_.jpg"]
# -- child 3 type: string
# ["MAIN","PT01","PT02","PT03","PT04","PT05","PT06"],-- is_valid: all not null
# -- child 0 type: string
# ["https://m.media-amazon.com/images/I/71EWIcjQTsL._AC_UL1500_.jpg","https://m.media-amazon.com/images/I/61dI3jV6+6L._AC_UL1500_.jpg"]
# -- child 1 type: string
# ["https://m.media-amazon.com/images/I/31+VOH41HcL._AC_.jpg","https://m.media-amazon.com/images/I/41UWgSImFSL._AC_.jpg"]
# -- child 2 type: string
# ["https://m.media-amazon.com/images/I/31+VOH41HcL._AC_SR38,50_.jpg","https://m.media-amazon.com/images/I/41UWgSImFSL._AC_SR38,50_.jpg"]
# -- child 3 type: string
# ["MAIN","PT01"]]
# store: ["CHUVORA","PrimeMed","KEZEF","VERO MONTE","SA106","Kranchungel","PUMA","joyliveCY","Twotwowin","ULTPEAK",...,"OTIOTI","Steve Madden","GRACE KARIN","commix.x","La Regis Jewelry","JIQUURY","Doctor Who","YuFalling","ATHLIO","Buxton"]
# details: -- is_valid: all not null
# -- child 0 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 1 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 2 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 3 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 4 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 5 type: string
# [null,null,"Adult",null,null,null,null,null,null,null,...,null,null,null,null,null,"Adult",null,null,null,"Adult"]
# -- child 6 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 7 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 8 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 9 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 10 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 11 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 12 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 13 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 14 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 15 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 16 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 17 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 18 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 19 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 20 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 21 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 22 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 23 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 24 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 25 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 26 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 27 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 28 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 29 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 30 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 31 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 32 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 33 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 34 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 35 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 36 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 37 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 38 type: struct<Climate Pledge Friendly: double, Climate Pledge Friendly: Apparel: double, Men's Wallets: double, Our Brands: double, Women's Activewear Leggings: double, Women's Activewear T-Shirts: double>
# -- is_valid:[false,false,false,false,false,false,false,false,false,false,...,false,false,false,false,false,false,false,false,false,false]
# -- child 0 type: double
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 1 type: double
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 2 type: double
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 3 type: double
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 4 type: double
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 5 type: double
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 39 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 40 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 41 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 42 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 43 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 44 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 45 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 46 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 47 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 48 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 49 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 50 type: string
# [null,null,"KEZEF",null,null,null,null,null,null,null,...,null,null,null,null,null,"JIQUURY",null,null,null,"Buxton"]
# -- child 51 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 52 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 53 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 54 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 55 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 56 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 57 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 58 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 59 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 60 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 61 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 62 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 63 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 64 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 65 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 66 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 67 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 68 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 69 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 70 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 71 type: string
# ...
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 416 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 417 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 418 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 419 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 420 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 421 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 422 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 423 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 424 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 425 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 426 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 427 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 428 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 429 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 430 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 431 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 432 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 433 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 434 type: string
# [null,null,"8 inch",null,null,null,null,null,null,null,...,null,null,null,null,null,"10 inches",null,null,null,null]
# -- child 435 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 436 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 437 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 438 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 439 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 440 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 441 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 442 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 443 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 444 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 445 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 446 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 447 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 448 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 449 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 450 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 451 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 452 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 453 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 454 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 455 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 456 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 457 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 458 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 459 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 460 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 461 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,"Charm,Simple",null,null,null,null]
# -- child 462 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 463 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 464 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 465 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 466 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 467 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 468 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 469 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 470 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 471 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 472 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 473 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 474 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 475 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 476 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 477 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 478 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 479 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 480 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 481 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 482 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 483 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 484 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 485 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 486 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 487 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 488 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 489 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 490 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 491 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 492 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 493 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 494 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 495 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 496 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 497 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 498 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 499 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 500 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 501 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 502 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 503 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 504 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 505 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 506 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 507 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 508 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 509 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 510 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 511 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 512 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 513 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 514 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 515 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 516 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 517 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 518 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 519 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 520 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 521 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 522 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 523 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 524 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 525 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 526 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 527 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 528 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 529 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 530 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 531 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 532 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# -- child 533 type: string
# [null,null,null,null,null,null,null,null,null,null,...,null,null,null,null,null,null,null,null,null,null]
# parent_asin: ["B00LOPVX74","B07B4JXK8D","B007ZSEQ4Q","B07F2BTFS9","B00XESJTDE","B089S8MFCQ","B01MZDN9Z4","B00N9X4XNU","B087M39LVV","B0799L7FMC",...,"B01GUP9ITW","B07Q758BZ8","B078HMV5H6","B08T7BT5D7","B077PFNBGN","B09J2LGN1F","B0012D5CH0","B01JW8FE6K","B08DK1ZN5L","B00K54OZCK"]
# ...

# %%
# load batch into pandas dataframe
df = batch.to_pandas()
df.columns
# Out:
# Index(['title', 'average_rating', 'rating_number', 'features', 'description',
#        'price', 'images', 'store', 'details', 'parent_asin',
#        'title_review_agg', 'user_id', 'timestamp', 'avg_rating_reviewers',
#        'coefvar_rating_reviewers', 'text_agg', 'text_weighted_agg',
#        'images_review_cln'],
#       dtype='object')

# %% [markdown]
# - 'title' and 'description would be used for text embedding.
#
# - 'image' column need some processing to retrieve images before embed

# %%
df['images'][0]
# Out:
# array([{'hi_res': 'https://m.media-amazon.com/images/I/61hlxr+VAoL._AC_UL1000_.jpg', 'large': 'https://m.media-amazon.com/images/I/51nk4aYpnbL._AC_.jpg', 'thumb': 'https://m.media-amazon.com/images/I/51nk4aYpnbL._AC_US40_.jpg', 'variant': 'MAIN'},
#        {'hi_res': 'https://m.media-amazon.com/images/I/61RwNTNuZOL._AC_UL1000_.jpg', 'large': 'https://m.media-amazon.com/images/I/41EW-AJGmEL._AC_.jpg', 'thumb': 'https://m.media-amazon.com/images/I/41EW-AJGmEL._AC_US40_.jpg', 'variant': 'PT01'},
#        {'hi_res': 'https://m.media-amazon.com/images/I/51rWHbgwIiL._AC_UL1000_.jpg', 'large': 'https://m.media-amazon.com/images/I/415DEob2AnL._AC_.jpg', 'thumb': 'https://m.media-amazon.com/images/I/415DEob2AnL._AC_US40_.jpg', 'variant': 'PT02'},
#        {'hi_res': 'https://m.media-amazon.com/images/I/51rWHbgwIiL._AC_UL1000_.jpg', 'large': 'https://m.media-amazon.com/images/I/415DEob2AnL._AC_.jpg', 'thumb': 'https://m.media-amazon.com/images/I/415DEob2AnL._AC_US40_.jpg', 'variant': 'PT03'},
#        {'hi_res': 'https://m.media-amazon.com/images/I/61LcUFVE8zL._AC_UL1000_.jpg', 'large': 'https://m.media-amazon.com/images/I/41H3qMlovOL._AC_.jpg', 'thumb': 'https://m.media-amazon.com/images/I/41H3qMlovOL._AC_US40_.jpg', 'variant': 'PT04'}],
#       dtype=object)

# %%
# an example to extract the first large image from the images column
df['first_large_image'] = df['images'].apply(lambda x: x.tolist()[0]['large'] if x.size > 0 else None)
df['first_large_image']
# Out:
# 0      https://m.media-amazon.com/images/I/51nk4aYpnb...
# 1      https://m.media-amazon.com/images/I/51b-BnwE4r...
# 2      https://m.media-amazon.com/images/I/41nYxugn7f...
# 3      https://m.media-amazon.com/images/I/41NLo0H7B1...
# 4      https://m.media-amazon.com/images/I/31Epv0yCkL...
#                              ...
# 995    https://m.media-amazon.com/images/I/41gVB2l1WP...
# 996    https://m.media-amazon.com/images/I/51b7SaP2DB...
# 997    https://m.media-amazon.com/images/I/31uPzIRRE6...
# 998    https://m.media-amazon.com/images/I/416BnKa-fL...
# 999    https://m.media-amazon.com/images/I/31+VOH41Hc...
# Name: first_large_image, Length: 1000, dtype: object

# %% [markdown]
# ## Text embedding with "text-embedding-3-large"

# %% [markdown]
# ### Try if OpenAI api work for you

# %%
from openai import OpenAI
client = OpenAI() # put your openai api key inside the parenthesis

# %%
EMBEDDING_MODEL = "text-embedding-3-large"

# %%
def create_embedding(text):
    response = client.embeddings.create(
        model=EMBEDDING_MODEL,
        input=text,
    )
    return response.data[0].embedding

# %%
test_embed = create_embedding("Hello, world!")
print(len(test_embed))
# Out:
# 3072

# %% [markdown]
# ## Full implementation code here:

# %%
pinecone_api_key = "your_pinecone_api_key_here"
pc = Pinecone(api_key=pinecone_api_key)
index = pc.Index("your_index_name_here")

# %%
import pyarrow.parquet as pq
from openai import OpenAI
import concurrent.futures
import pandas as pd
import logging
import time

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

client = OpenAI() # your openai api key here
EMBEDDING_MODEL = "text-embedding-3-large"
pinecone_api_key = "your_pinecone_api_key_here" ##
pc = Pinecone(api_key=pinecone_api_key)
pinecone_index = pc.Index("your_index_name_here") ###

# %%
def fetch_existing_ids_from_pinecone(pinecone_index):

    existing_ids = set()
    for ids in pinecone_index.list():
        for id in ids:
            existing_ids.add(id)

    return existing_ids

def read_ids_from_dataset(parquet_file):
    dataset_ids = set()
    for batch in parquet_file.iter_batches(columns=['parent_asin'], batch_size=5000):
        df = batch.to_pandas()
        dataset_ids.update(df['parent_asin'])
    return dataset_ids

# %%
def read_ids_from_dataset(parquet_file):
    dataset_ids = set()
    for batch in parquet_file.iter_batches(columns=['parent_asin'], batch_size=5000):
        df = batch.to_pandas()
        dataset_ids.update(df['parent_asin'])
    return dataset_ids

dataset_ids = read_ids_from_dataset(parquet_file)
missing_ids = dataset_ids.difference(existing_id) # incase you have already indexed some of the ids

# Set of target product IDs
target_product_ids = missing_ids  # Fill with dataset_ids if you want to index all products

# %%
# Function to create embedding using OpenAI
def create_embedding(text):
    try:
        response = client.embeddings.create(
            model=EMBEDDING_MODEL,
            input=text,
        )
        return response.data[0].embedding
    except Exception as e:
        logging.error(f"Failed to create embedding: {e}")
        return None

# Load the Parquet file 
parquet_file = pq.ParquetFile('data/amazon_fashion_clean_051624.parquet') #### You can change the path to the parquet file

# Define the number of rows per batch
batch_size = 1000

# Batch size for Pinecone upserts
pinecone_batch_size = 200 # use 200 since the data is large
upsert_buffer = []

def process_row(row):
    parent_asin = row.get('parent_asin', 'unknown_id')
    if parent_asin in target_product_ids:
        title = row.get('title', '')
        description = row.get('description', '')
        store = row.get('store', 'N/A')
        if store is None:
            store = 'N/A'
        average_rating = row.get('average_rating', 0.0)
        text = f"{title}: {description}"
        # Truncate text to 300 tokens
        tokens = text.split()[:300]
        truncated_text = " ".join(tokens)

        # Create embedding
        embedding = create_embedding(truncated_text)
        if embedding is None:
            return None

        return {
            "id": parent_asin,
            "values": embedding,
            "metadata": {
                "title": title,
                "store": store,
                "average_rating": average_rating
            }
        }

def upsert_to_pinecone(batch):
    retry_attempts = 3
    for attempt in range(retry_attempts):
        try:
            if batch:
                pinecone_index.upsert(vectors=batch)
                logging.info("Upsert batch successful")
                break
        except Exception as e:
            logging.error(f"Upsert failed: {e}, retrying ({attempt+1}/{retry_attempts})")
            time.sleep(2 ** attempt)  # Exponential backoff

# %%
# Create a ThreadPoolExecutor for parallel processing
executor = concurrent.futures.ThreadPoolExecutor(max_workers=200)

# Iterator to process the parquet file in batches
for batch in parquet_file.iter_batches(batch_size=batch_size):
    df = pd.DataFrame(batch.to_pandas())
    futures = [executor.submit(process_row, row) for index, row in df.iterrows()]
    results = [future.result() for future in concurrent.futures.as_completed(futures)]

    for result in results:
        if result is not None:
            upsert_buffer.append(result)

            # Check if buffer reached Pinecone batch size
            if len(upsert_buffer) >= pinecone_batch_size:
                upsert_to_pinecone(upsert_buffer)
                upsert_buffer = []

# Upsert any remaining items in the buffer
upsert_to_pinecone(upsert_buffer)

# %% [markdown]
# ### Image embedding
#
# - This is a little more complicated as this demo code is running locally using torch cuda environment.
#
# - Prepare the `sentence_transformers` pacakge and torch based on your own computer or working environment

# %%
import ijson
import json
import numpy as np
import cv2 ### ! pip install opencv-python-headless
import urllib.request
from PIL import Image
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
import torch
from pinecone import Pinecone

# %%
torch.__version__
# Out:
# '2.3.0'

# %%
torch.cuda.get_device_name(torch.cuda.current_device()) # check if you have a gpu
# Out:
# 'NVIDIA GeForce RTX 4090'

# %%
model = SentenceTransformer('clip-ViT-B-32')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
# Out:
# SentenceTransformer(
#   (0): CLIPModel()
# )

# %% [markdown]
# ### First, we can create a list of urls from the parquet file, store in a json so if can be processed cleanly later

# %%
import pyarrow.parquet as pq
import pandas as pd
import json

# Path to your Parquet file
parquet_file_path = 'data/amazon_fashion_clean_051624.parquet'
parquet_file = pq.ParquetFile(parquet_file_path)

# Batch size for reading
batch_size = 20000

# Dictionary to hold all product details
product_details = {}

# Iterator to go through the Parquet file in batches
iterator = parquet_file.iter_batches(batch_size=batch_size)

batch_count = 0

for batch in iterator:
    # Convert the current batch to a pandas DataFrame
    df = batch.to_pandas()
    
    # Extract the first large image link
    df['first_large_image'] = df['images'].apply(lambda x: x.tolist()[0]['large'] if x.size > 0 else None)
    
    # Filter the columns needed for the final output
    df_final = df[['parent_asin', 'title', 'first_large_image']]
    
    # Update the dictionary with the data from this batch
    for _, row in df_final.iterrows():
        asin = row['parent_asin']
        product_details[asin] = {'title': row['title'], 'image_link': row['first_large_image']}

    batch_count += 1

    print(f'Processed batch {batch_count}')

products_list = []
for asin, details in product_details.items():
    products_list.append({
        "id": asin,
        "title": details['title'],
        "image_link": details['image_link']
    })

# Path where you want to save the JSON file
json_file_path = 'output/product_details_array.json' ## modify your file name

# Write the dictionary to a JSON file
with open(json_file_path, 'w') as json_file:
    json.dump(products_list, json_file, indent=4)

print(f'Product details have been successfully written to {json_file_path}')

# %% [markdown]
# This output file would be passed into the process below to create clip embedding and upload to pinecone

# %%
def fetch_images(urls):
    images = []
    for url in tqdm(urls):
        try:
            resp = urllib.request.urlopen(url)
            image = np.asarray(bytearray(resp.read()), dtype="uint8")
            image = cv2.imdecode(image, cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            images.append(Image.fromarray(image))
        except Exception as e:
            print(f"Failed to load {url}: {str(e)}")
    return images

def upsert_to_pinecone(pinecone_index, batch, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            pinecone_index.upsert(vectors=batch)
            return True
        except Exception as e:
            attempt += 1
            print(f"Upsert failed on attempt {attempt}: {str(e)}")
            time.sleep(2 ** attempt)
    return False

def process_images_in_batches(json_file, batch_size=10, progress_file='progress_record.json'):
    urls = []
    keys = []
    titles = []
    count = 0
    processed_keys = set()

    # Load progress if exists
    try:
        with open(progress_file, 'r') as file:
            processed_keys = set(json.load(file))
    except FileNotFoundError:
        print("No progress file found. Starting fresh.")

    with open(json_file, 'rb') as file:
        items = ijson.items(file, 'item')
        for item in items:
            if item['id'] not in processed_keys:
                urls.append(item['image_link'])
                keys.append(item['id'])
                titles.append(item['title'])
                count += 1

            if count >= batch_size:
                images = fetch_images(urls)
                embeddings = model.encode(images, batch_size=len(images), convert_to_tensor=True, show_progress_bar=True)
                batch = [
                    {"id": key, "values": embedding.cpu().numpy().tolist(), "metadata": {"title": title}}
                    for key, embedding, title in zip(keys, embeddings, titles)
                ]
                if upsert_to_pinecone(pinecone_index, batch):
                    processed_keys.update(keys)
                    with open(progress_file, 'w') as f:
                        json.dump(list(processed_keys), f)
                
                urls = []
                keys = []
                titles = []
                count = 0

        if urls:
            images = fetch_images(urls)
            embeddings = model.encode(images, batch_size=len(images), convert_to_tensor=True, show_progress_bar=True)
            batch = [
                {"id": key, "values": embedding.cpu().numpy().tolist(), "metadata": {"title": title}}
                for key, embedding, title in zip(keys, embeddings, titles)
            ]
            if upsert_to_pinecone(pinecone_index, batch):
                processed_keys.update(keys)
                with open(progress_file, 'w') as f:
                    json.dump(list(processed_keys), f)
            print(f"Upserted final batch of size {len(images)}")

# %%
process_images_in_batches('output/product_details_array.json', batch_size=128)
